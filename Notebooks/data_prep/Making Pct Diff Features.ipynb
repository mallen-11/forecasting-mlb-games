# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

import datetime as dt

# %%
mlb_games = pd.read_csv('../../data/saved_datasets/train_1.csv')
mlb_games = mlb_games.sort_values(by='date')

# %%
mlb_games.head()
# Out:
#          date     Y    M    D home_team away_team  home_win home_pitcher  \
# 0  2001-04-01  2001  4.0  1.0       TOR       TEX       1.0    loaizes01
# 1  2001-04-02  2001  4.0  2.0       SEA       OAK       1.0    garcifr03
# 2  2001-04-02  2001  4.0  2.0       NYA       KCA       1.0    clemero02
# 3  2001-04-02  2001  4.0  2.0       CIN       ATL       0.0    harnipe01
# 4  2001-04-02  2001  4.0  2.0       CHN       WAS       0.0    liebejo01
#
#   away_pitcher  home_elo  ...  pitcher_home_ERA_offset1game  \
# 0    helliri01  1499.563  ...                           NaN
# 1    hudsoti01  1519.464  ...                           NaN
# 2    suppaje01  1529.511  ...                           NaN
# 3    burkejo03  1527.274  ...                           NaN
# 4    vazquja01  1462.510  ...                           NaN
#
#    pitcher_home_WHIP_offset1game  pitcher_home_IP_offset1game  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#    pitcher_home_aLI_offset1game  pitcher_home_WPA_offset1game  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    pitcher_away_ERA_offset1game  pitcher_away_WHIP_offset1game  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
#
#    pitcher_away_IP_offset1game  pitcher_away_aLI_offset1game  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#    pitcher_away_WPA_offset1game
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
# [5 rows x 57 columns]

# %%
mlb_games.columns
# Out:
# Index(['date', 'Y', 'M', 'D', 'home_team', 'away_team', 'home_win',
#        'home_pitcher', 'away_pitcher', 'home_elo', 'away_elo', 'home_avg',
#        'away_avg', 'home_obp', 'away_obp', 'home_slg', 'away_slg', 'home_iso',
#        'away_iso', 'elo_diff', 'elo_pct_diff', 'avg_diff', 'obp_diff',
#        'slg_diff', 'avg_pct_diff', 'obp_pct_diff', 'slg_pct_diff', 'home_rest',
#        'away_rest', 'away_team_season_game_num', 'home_team_season_game_num',
#        'home_ERA_offset1year', 'home_WHIP_offset1year', 'away_ERA_offset1year',
#        'away_WHIP_offset1year', 'home_W-L-pct_offset1year',
#        'home_Avg_Attendance_offset1year', 'home_R_offset1year',
#        'home_RA_offset1year', 'home_Rank_offset1year', 'home_FP_offset1year',
#        'away_W-L-pct_offset1year', 'away_Avg_Attendance_offset1year',
#        'away_R_offset1year', 'away_RA_offset1year', 'away_Rank_offset1year',
#        'away_FP_offset1year', 'pitcher_home_ERA_offset1game',
#        'pitcher_home_WHIP_offset1game', 'pitcher_home_IP_offset1game',
#        'pitcher_home_aLI_offset1game', 'pitcher_home_WPA_offset1game',
#        'pitcher_away_ERA_offset1game', 'pitcher_away_WHIP_offset1game',
#        'pitcher_away_IP_offset1game', 'pitcher_away_aLI_offset1game',
#        'pitcher_away_WPA_offset1game'],
#       dtype='object')

# %%
mlb_games['home_ops'] = mlb_games['home_slg'] + mlb_games['home_obp']
mlb_games['away_ops'] = mlb_games['away_slg'] + mlb_games['away_obp']

# %%
mlb_games['home_RD'] = mlb_games['home_R_offset1year'] - mlb_games['home_RA_offset1year']
mlb_games['away_RD'] = mlb_games['away_R_offset1year'] - mlb_games['away_RA_offset1year']

# %%
mlb_games = mlb_games.replace([np.inf, -np.inf], 1000)

# %%
# > 0 = home is better
mlb_games['pitcher_WHIP_diff'] = (mlb_games['pitcher_home_WHIP_offset1game'] - mlb_games['pitcher_away_WHIP_offset1game'])
mlb_games['pitcher_ERA_diff'] = (mlb_games['pitcher_home_ERA_offset1game'] - mlb_games['pitcher_away_ERA_offset1game'])
mlb_games['pitcher_IP_diff'] = (mlb_games['pitcher_home_IP_offset1game'] - mlb_games['pitcher_away_IP_offset1game'])
#mlb_games['team_WHIP_diff'] = (mlb_games['team_home_WHIP_offset1year'] - mlb_games['team_away_WHIP_offset1year'])
mlb_games['W-L_diff'] = (mlb_games['home_W-L-pct_offset1year'] - mlb_games['away_W-L-pct_offset1year'])
#mlb_games['team_ERA_diff'] = (mlb_games['team_home_ERA_offset1year'] - mlb_games['team_away_ERA_offset1year'])
mlb_games['ops_diff'] = mlb_games['home_ops'] - mlb_games['away_ops']
mlb_games['RD_diff'] = mlb_games['home_RD'] - mlb_games['away_RD']
mlb_games['FP_diff'] = mlb_games['home_FP_offset1year'] - mlb_games['away_FP_offset1year']
mlb_games['Rank_diff'] = mlb_games['home_Rank_offset1year'] - mlb_games['away_Rank_offset1year']
mlb_games['WPA_diff'] = mlb_games['pitcher_home_WPA_offset1game'] - mlb_games['pitcher_away_WPA_offset1game']
mlb_games['aLI_diff'] = mlb_games['pitcher_home_aLI_offset1game'] - mlb_games['pitcher_away_aLI_offset1game']


# scaling doesn't matter for many cases
mlb_games['pitcher_WHIP_pct_diff'] = (mlb_games['pitcher_WHIP_diff'])/(mlb_games['pitcher_home_WHIP_offset1game'])*100
mlb_games['pitcher_ERA_pct_diff'] = (mlb_games['pitcher_ERA_diff'])/(mlb_games['pitcher_home_ERA_offset1game'])*100
mlb_games['pitcher_IP_pct_diff'] = (mlb_games['pitcher_IP_diff'])/(mlb_games['pitcher_home_IP_offset1game'])*100
#mlb_games['team_WHIP_diff'] = (mlb_games['team_WHIP_diff'])/(mlb_games['team_home_WHIP_offset1year'])*100
#mlb_games['team_ERA_pct_diff'] = (mlb_games['team_ERA_diff'])/(mlb_games['team_home_ERA_offset1year'])*100
mlb_games['ops_pct_diff'] = (mlb_games['ops_diff'] / mlb_games['home_ops'])*100
#mlb_games['attendance_pct_diff'] = (mlb_games['attendance_diff'] / mlb_games['home_Avg_Attendance_offset1year'])*100
mlb_games['RD_pct_diff'] = (mlb_games['RD_diff'] / mlb_games['home_RD'])*100
mlb_games['FP_pct_diff'] = (mlb_games['FP_diff'] / mlb_games['home_FP_offset1year'])*100
mlb_games['Rank_pct_diff'] = (mlb_games['Rank_diff'] / mlb_games['home_Rank_offset1year'])*100
mlb_games['WPA_pct_diff'] = (mlb_games['WPA_diff'] / mlb_games['pitcher_home_WPA_offset1game'])*100
mlb_games['aLI_pct_diff'] = (mlb_games['aLI_diff'] - mlb_games['pitcher_home_aLI_offset1game'])*100

# %%
mlb_games.head()
# Out:
#          date     Y    M    D home_team away_team  home_win home_pitcher  \
# 0  2001-04-01  2001  4.0  1.0       TOR       TEX       1.0    loaizes01
# 1  2001-04-02  2001  4.0  2.0       SEA       OAK       1.0    garcifr03
# 2  2001-04-02  2001  4.0  2.0       NYA       KCA       1.0    clemero02
# 3  2001-04-02  2001  4.0  2.0       CIN       ATL       0.0    harnipe01
# 4  2001-04-02  2001  4.0  2.0       CHN       WAS       0.0    liebejo01
#
#   away_pitcher  home_elo  ...  pitcher_home_ERA_offset1game  \
# 0    helliri01  1499.563  ...                           NaN
# 1    hudsoti01  1519.464  ...                           NaN
# 2    suppaje01  1529.511  ...                           NaN
# 3    burkejo03  1527.274  ...                           NaN
# 4    vazquja01  1462.510  ...                           NaN
#
#    pitcher_home_WHIP_offset1game  pitcher_home_WPA_offset1game  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
#
#    pitcher_away_ERA_offset1game  pitcher_away_WHIP_offset1game  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
#
#    pitcher_away_WPA_offset1game  home_ops  away_ops  home_RD  away_RD
# 0                           NaN  0.805669  0.792502    -47.0   -126.0
# 1                           NaN  0.796607  0.811646    127.0    134.0
# 2                           NaN  0.797902  0.766185     57.0    -51.0
# 3                           NaN  0.784840  0.766353     60.0     96.0
# 4                           NaN  0.741700  0.751356   -140.0      NaN
#
# [5 rows x 57 columns]

# %%
mlb_games.to_csv('../../data/model_df10.csv', index=False)

# %%
mlb_games.dtypes
# Out:
# date                                object
# Y                                    int64
# M                                  float64
# D                                  float64
# home_team                           object
# away_team                           object
# home_win                           float64
# home_pitcher                        object
# away_pitcher                        object
# home_elo                           float64
# away_elo                           float64
# home_avg                           float64
# away_avg                           float64
# home_obp                           float64
# away_obp                           float64
# home_slg                           float64
# away_slg                           float64
# home_iso                           float64
# away_iso                           float64
# elo_diff                           float64
# elo_pct_diff                       float64
# avg_diff                           float64
# obp_diff                           float64
# slg_diff                           float64
# avg_pct_diff                       float64
# obp_pct_diff                       float64
# slg_pct_diff                       float64
# home_rest                          float64
# away_rest                          float64
# away_team_season_game_num            int64
# home_team_season_game_num            int64
# home_ERA_offset1year               float64
# home_WHIP_offset1year              float64
# away_ERA_offset1year               float64
# away_WHIP_offset1year              float64
# home_W-L-pct_offset1year           float64
# home_Avg_Attendance_offset1year    float64
# home_R_offset1year                 float64
# home_RA_offset1year                float64
# home_Rank_offset1year              float64
# home_FP_offset1year                float64
# away_W-L-pct_offset1year           float64
# away_Avg_Attendance_offset1year    float64
# away_R_offset1year                 float64
# away_RA_offset1year                float64
# away_Rank_offset1year              float64
# away_FP_offset1year                float64
# pitcher_home_ERA_offset1game       float64
# pitcher_home_WHIP_offset1game      float64
# pitcher_home_WPA_offset1game       float64
# pitcher_away_ERA_offset1game       float64
# pitcher_away_WHIP_offset1game      float64
# pitcher_away_WPA_offset1game       float64
# home_ops                           float64
# away_ops                           float64
# home_RD                            float64
# away_RD                            float64
# dtype: object

# %%
mlb_games['pitcher_home_ERA_offset1game'] = mlb_games['pitcher_home_ERA_offset1game'].replace({'---':None})

# %%
mlb_games['pitcher_away_ERA_offset1game'] = mlb_games['pitcher_away_ERA_offset1game'].replace({'---':None})

# %%
mlb_games['pitcher_away_ERA_offset1game'] = mlb_games['pitcher_away_ERA_offset1game'].astype(float)

# %%
mlb_games['pitcher_home_ERA_offset1game'] = mlb_games['pitcher_home_ERA_offset1game'].astype(float)
