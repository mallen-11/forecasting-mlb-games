# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import datetime as dt

#import pybaseball as pyb

# %%
yearly_pitching_df = pd.read_csv('../data/fg_pitchers.csv')

# %%
yearly_pitching_df.head()
# Out:
#               Name       Team  W   L  SV   G  GS     IP   K/9  BB/9  ...  \
# 0  John Frascatore  Blue Jays  2   4   0  60   0   73.0  3.70  4.07  ...
# 1        Kip Wells  White Sox  6   9   0  20  20   98.2  6.48  5.29  ...
# 2      Ramon Ortiz     Angels  8   6   0  18  18  111.1  5.90  4.45  ...
# 3        Omar Daal      - - -  4  19   0  32  28  167.0  5.17  3.88  ...
# 4         Lou Pote     Angels  1   1   1  32   1   50.1  7.87  3.04  ...
#
#     LOB%  GB% HR/FB  EV   ERA   FIP  xFIP  WAR  playerid  year
# 0  70.8%  NaN   NaN NaN  5.42  6.45   NaN -1.1   1004304  2000
# 1  66.7%  NaN   NaN NaN  6.02  5.50   NaN  0.7      1012  2000
# 2  65.7%  NaN   NaN NaN  5.09  5.46   NaN  0.7        27  2000
# 3  63.7%  NaN   NaN NaN  6.14  5.46   NaN  0.7       646  2000
# 4  72.6%  NaN   NaN NaN  3.40  3.43   NaN  0.7        30  2000
#
# [5 rows x 22 columns]

# %%
yearly_pitching_df.columns
# Out:
# Index(['Name', 'Team', 'W', 'L', 'SV', 'G', 'GS', 'IP', 'K/9', 'BB/9', 'HR/9',
#        'BABIP', 'LOB%', 'GB%', 'HR/FB', 'EV', 'ERA', 'FIP', 'xFIP', 'WAR',
#        'playerid', 'year'],
#       dtype='object')

# %%
#yearly_pitching_df = pyb.pitching_stats(2000, 2019)

# %%
#yearly_pitching_df['WHIP'] = (yearly_pitching_df['H'] + yearly_pitching_df['BB'])/yearly_pitching_df['IP']
yearly_pitching_df['IP_Start'] = (yearly_pitching_df['IP'])/yearly_pitching_df['GS']
yearly_pitching_df['HR'] = (yearly_pitching_df['HR/9']*yearly_pitching_df['IP'])*9
yearly_pitching_df['SO'] = (yearly_pitching_df['K/9']*yearly_pitching_df['IP'])*9
yearly_pitching_df['BB'] = (yearly_pitching_df['BB/9']*yearly_pitching_df['IP'])*9
yearly_pitching_df['K/BB'] = (yearly_pitching_df['SO'])/yearly_pitching_df['BB']



#yearly_pitching_df['FIP_NORM'] = (13*yearly_pitching_df['HR'] + 
#                           3*(yearly_pitching_df['BB'] + yearly_pitching_df['HBP']) - 
#                            2*yearly_pitching_df['SO'])/yearly_pitching_df['IP']

# %%
yearly_pitching_df.head()
# Out:
#               Name       Team  W   L  SV   G  GS     IP   K/9  BB/9  ...  \
# 0  John Frascatore  Blue Jays  2   4   0  60   0   73.0  3.70  4.07  ...
# 1        Kip Wells  White Sox  6   9   0  20  20   98.2  6.48  5.29  ...
# 2      Ramon Ortiz     Angels  8   6   0  18  18  111.1  5.90  4.45  ...
# 3        Omar Daal      - - -  4  19   0  32  28  167.0  5.17  3.88  ...
# 4         Lou Pote     Angels  1   1   1  32   1   50.1  7.87  3.04  ...
#
#     FIP  xFIP  WAR playerid  year   IP_Start        HR        SO        BB  \
# 0  6.45   NaN -1.1  1004304  2000        inf  1136.610  2430.900  2673.990
# 1  5.50   NaN  0.7     1012  2000   4.910000  1210.806  5727.024  4675.302
# 2  5.46   NaN  0.7       27  2000   6.172222  1459.854  5899.410  4449.555
# 3  5.46   NaN  0.7      646  2000   5.964286  2104.200  7770.510  5831.640
# 4  3.43   NaN  0.7       30  2000  50.100000   324.648  3548.583  1370.736
#
#        K/BB
# 0  0.909091
# 1  1.224953
# 2  1.325843
# 3  1.332474
# ...

# %%
yearly_pitching_df.columns
# Out:
# Index(['Name', 'Team', 'W', 'L', 'SV', 'G', 'GS', 'IP', 'K/9', 'BB/9', 'HR/9',
#        'BABIP', 'LOB%', 'GB%', 'HR/FB', 'EV', 'ERA', 'FIP', 'xFIP', 'WAR',
#        'playerid', 'year', 'IP_Start', 'HR', 'SO', 'BB', 'K/BB'],
#       dtype='object')

# %%
pitchers_year_df = yearly_pitching_df[['Name', 'playerid', 'year', 'Team', 
                               'W', 'L', 'G', 'GS', 'IP', 'IP_Start','WAR',
                                'ERA', 'FIP', 'xFIP', 'SO', 'K/9', 'BB', 'K/BB', 'HR/9']]

pitchers_year_df = pitchers_year_df.rename({'year': 'Y','Team': 'team', 'SO': 'K'}, axis = 1)

# %%
pitchers_summary = pd.read_csv('../data/pitchers_summary.csv')

# %%
pitchers_keys = pitchers_summary[['Name', 'key_mlbam', 'key_retro', 'key_bbref', 'key_fangraphs']]

# %%
pitchers_keys.head()
# Out:
#            Name  key_mlbam key_retro  key_bbref  key_fangraphs
# 0  A.J. Burnett   150359.0  burna001  burnea.01          512.0
# 1  A.J. Griffin   456167.0  grifa002  griffaj01        11132.0
# 2    Aaron Cook   346871.0  cooka002   cookaa01         1571.0
# 3  Aaron Harang   421685.0  haraa001  haranaa01         1451.0
# 4    Aaron Nola   605400.0  nolaa001   nolaaa01        16149.0

# %%
pitchers_df = pitchers_keys.merge(pitchers_year_df, how='outer')

# %%
pitchers_df.head()
# Out:
#            Name  key_mlbam key_retro  key_bbref  key_fangraphs  playerid  \
# 0  A.J. Burnett   150359.0  burna001  burnea.01          512.0       512
# 1  A.J. Burnett   150359.0  burna001  burnea.01          512.0       512
# 2  A.J. Burnett   150359.0  burna001  burnea.01          512.0       512
# 3  A.J. Burnett   150359.0  burna001  burnea.01          512.0       512
# 4  A.J. Burnett   150359.0  burna001  burnea.01          512.0       512
#
#       Y     team   W   L  ...  IP_Start  WAR   ERA   FIP  xFIP          K  \
# 0  2000  Marlins   3   7  ...  6.323077  0.9  4.79  4.68   NaN   4594.158
# 1  2001  Marlins  11  12  ...  6.411111  1.4  4.05  4.63   NaN  10360.035
# 2  2002  Marlins  12   9  ...  7.037931  4.8  3.30  3.19  3.73  16421.886
# 3  2003  Marlins   0   2  ...  5.750000  0.1  4.70  4.94  5.15   1701.540
# 4  2004  Marlins   7   6  ...  6.315789  2.9  3.68  3.19  3.45   9158.400
#
#     K/9        BB      K/BB  HR/9
# 0  6.21  3543.642  1.296451  0.87
# ...

# %%
pitchers_df.to_csv('../data/yearly_pitchers_df.csv')

# %%
mlb_games = pd.read_csv('../data/mlb_games_df.csv', index_col = 'Unnamed: 0')

# %%
mlb_games.head()
# Out:
#          date     Y  M  D home_team away_team   home_pitcher  away_pitcher  \
# 0  2001-04-01  2001  4  1       TOR       TEX       loaie001      hellr001
# 1  2001-04-02  2001  4  2       SFN       SDN       hernl003      willw001
# 2  2001-04-02  2001  4  2       SEA       OAK  Freddy Garcia    Tim Hudson
# 3  2001-04-02  2001  4  2       NYA       KCA       clemr001      suppj001
# 4  2001-04-02  2001  4  2       LAN       MIL       parkc002  Jamey Wright
#
#    home_elo  away_elo  ...  away_slg  home_iso  away_iso  elo_diff  avg_diff  \
# 0  1499.563  1479.163  ...  0.443116  0.192927  0.161597    20.400 -0.008060
# 1  1540.841  1492.800  ...  0.398252  0.192446  0.146424    48.041  0.024251
# 2  1519.464  1534.696  ...  0.454237  0.170727  0.186092   -15.232 -0.000864
# 3  1529.511  1493.152  ...  0.421482  0.171189  0.136214    36.359 -0.010188
# 4  1515.925  1490.396  ...  0.400071  0.172233  0.156534    25.529  0.010660
#
# ...

# %%
for col in ['IP_Start', 'ERA', 'FIP', 'WAR', 'K/9', 'HR/9', 'K/BB']:
    mlb_games['home_p_' + col] = float(0)
    mlb_games['away_p_' + col] = float(0)
    mlb_games[col + '_difference'] = float(0)
    mlb_games[col + '_difference_PCT'] = float(0)

# %%
pitchers_df.columns
# Out:
# Index(['Name', 'key_mlbam', 'key_retro', 'key_bbref', 'key_fangraphs',
#        'playerid', 'Y', 'team', 'W', 'L', 'G', 'GS', 'IP', 'IP_Start', 'WAR',
#        'ERA', 'FIP', 'xFIP', 'K', 'K/9', 'BB', 'K/BB', 'HR/9'],
#       dtype='object')

# %%
pitcher=0
for i in range(len(mlb_games)):
    for k in range(len(pitchers_df)):
        if (mlb_games['home_pitcher'][i] == pitchers_df['Name'][k]):
            pitcher = pitchers_df[pitchers_df['Name'] == mlb_games['home_pitcher'][i]]
            pitcher = pitcher.reset_index(drop=True)
        elif (mlb_games['home_pitcher'][i] == pitchers_df['key_retro'][k]):
            pitcher = pitchers_df[pitchers_df['key_retro'] == mlb_games['home_pitcher'][i]]
            pitcher = pitcher.reset_index(drop=True)
        else:
            break
        
        if mlb_games['Y'][i] == (int(pitcher['Y'][k])-1):
            stats = pitcher[pitcher['Y'] == (int(pitcher['Y'][k])-1)][['IP_Start', 'WAR','ERA', 'FIP','K/9', 'K/BB', 'HR/9']]
            stats = stats.rename({'IP_Start': 'home_p_IP_Start', 'WAR':'home_p_WAR','ERA': 'home_p_ERA', 
                          'FIP':'home_p_FIP','K/9':'home_p_K/9',
                          'K/BB':'home_p_K/BB', 'HR/9':'home_p_HR/9'}, axis=1)
            for l in stats.columns:
                mlb_games[l][i] = stats[l]
# Out:
# /opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# REALLY SLOW PIECE OF CODE
import time 
start_time = time.time()
for i in range(len(post_2001_games)):
    if (i % 4000 == 0):
        year_end = time.time()
        print('first ' + str(i) + ' total: ' + str(round((year_end - start_time)*1000)/1000))
    for col in ['IP_Start', 'ERA', 'FIP', 'WHIP', 'BAA', 'K9', 'HR9', 'K/BB']:
        home_pitcher = lookup_stats(post_2001_games.loc[i, 'Y'], post_2001_games.loc[i, 'home_pitcher_id'])
        away_pitcher = lookup_stats(post_2001_games.loc[i, 'Y'], post_2001_games.loc[i, 'away_pitcher_id'])
        
        try:
            post_2001_games.loc[i, 'home_p_' + col] = home_pitcher.loc[0, col]
        except KeyError:
            post_2001_games.loc[i, 'home_p_' + col] = PITCHERS[
                (PITCHERS.Y == post_2001_games.loc[i, 'Y'])].mean()[col]
            post_2001_games.loc[i, 'missing_data'] = 1
        try:
            post_2001_games.loc[i, 'away_p_' + col] = away_pitcher.loc[0, col]
        except KeyError:
            post_2001_games.loc[i, 'away_p_' + col] = PITCHERS[
                (PITCHERS.Y == post_2001_games.loc[i, 'Y'])].mean()[col]
            post_2001_games.loc[i, 'missing_data'] = 1

# %%
p = pd.DataFrame({'x':[0,0,0], 'y':[0,0,0], 'z': [1,2,3]})
d = pd.DataFrame({'x':[1,2,3], 'y':[1,2,3]})

# %%
df = p.join(d, how='left', on='x', rsuffix='')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-200-4c13b7ee7723> in <module>
# ----> 1 df = p.join(d, how='left', on='x', rsuffix='')
#
# /opt/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7866         """
#    7867         return self._join_compat(
# -> 7868             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7869         )
#    7870
#
# /opt/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7889                 right_index=True,
#    7890                 suffixes=(lsuffix, rsuffix),
# -> 7891                 sort=sort,
#    7892             )
#    7893         else:
#
# ...

# %%
df
# Out:
#    x  y    z
# 0  0  0  1.0
# 1  0  0  2.0
# 2  0  0  3.0
# 3  1  1  NaN
# 4  2  2  NaN
# 5  3  3  NaN

# %%
for _ in range
